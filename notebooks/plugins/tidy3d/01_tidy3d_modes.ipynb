# %% [markdown]
# # Tidy3D mode solver
#
# Tidy3d comes with an open source FDFD [mode solver](https://docs.flexcompute.com/projects/tidy3d/en/latest/notebooks/ModeSolver.html)
#
# ## Waveguides
#
# Guided Electromagnetic modes are the ones that have an effective index larger than the cladding of the waveguide
#
# Here is a waveguide of Silicon (n=3.4) surrounded by SiO2 (n=1.44) cladding
#
# For a 220 nm height x 450 nm width the effective index is 2.466

# %%
import gdsfactory.simulation.gtidy3d as gt
import matplotlib.pyplot as plt

nm = 1e-3
# Out:
# 2023-01-03 02:16:05.047 | INFO     | gdsfactory.config:<module>:48 - Load '/home/runner/work/gdsfactory/gdsfactory/gdsfactory' 6.17.0
# [02:16:06] INFO     Using client version: 1.8.1                                                     ]8;id=176274;file:///usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/tidy3d/__init__.py\__init__.py]8;;\:]8;id=359631;file:///usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/tidy3d/__init__.py#112\112]8;;\
# 2023-01-03 02:16:06.966 | INFO     | gdsfactory.simulation.gtidy3d:<module>:54 - Tidy3d '1.8.1' installed at ['/usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/tidy3d']

# %%
strip = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    ncore="si",
    nclad="sio2",
)
strip.plot_index()

# %%
strip.plot_Ex(0)  # TE
strip.plot_Ey(1)  # TM
# Out:
# 2023-01-03 02:16:07.268 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/32ad155b.npz mode data from file cache.

# %%
rib = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.15,
    ncore="si",
    nclad="sio2",
)
rib.plot_index()

# %%
rib.plot_Ex(mode_index=0)
rib.plot_Ey(mode_index=0)
# Out:
# 2023-01-03 02:16:07.983 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/56153e53.npz mode data from file cache.

# %%
nitride = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=1.0,
    wg_thickness=0.4,
    slab_thickness=0.0,
    ncore="si",
    nclad="sio2",
)
nitride.plot_index()
nitride.plot_Ex(0)
nitride.plot_Ey(0)
# Out:
# 2023-01-03 02:16:08.690 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/91138828.npz mode data from file cache.

# %% [markdown]
# ## Sweep width
#
# You can sweep the waveguide width and compute the modes.
#
# By increasing the waveguide width, the waveguide supports many more TE and TM modes. Where TE modes have a dominant Ex field and TM modes have larger Ey fields.
#
# Notice that waveguides wider than 0.450 um support more than one TE mode. Therefore the maximum width for single mode operation is 0.450 um.

# %%
df = gt.modes.sweep_width(
    width1=200 * nm,
    width2=1000 * nm,
    steps=11,
    wavelength=1.55,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore="si",
    nclad="sio2",
)
gt.modes.plot_sweep_width(
    width1=200 * nm,
    width2=1000 * nm,
    steps=11,
    wavelength=1.55,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore="si",
    nclad="sio2",
)
plt.axhline(y = 1.44, color = 'k', linestyle = '--')
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-01-03 02:16:09.255 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/10e5b441.npz mode data from file cache.
# 2023-01-03 02:16:09.276 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/33ea7062.npz mode data from file cache.
# 2023-01-03 02:16:09.297 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/8a134890.npz mode data from file cache.
# 2023-01-03 02:16:09.318 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/548eec24.npz mode data from file cache.
# 2023-01-03 02:16:09.339 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/e63d47fe.npz mode data from file cache.
# 2023-01-03 02:16:09.361 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/accb98e4.npz mode data from file cache.
# 2023-01-03 02:16:09.382 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/6c77208e.npz mode data from file cache.
# 2023-01-03 02:16:09.403 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/26c31481.npz mode data from file cache.
# 2023-01-03 02:16:09.425 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d6a9a5e1.npz mode data from file cache.
# 2023-01-03 02:16:09.446 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d408cef4.npz mode data from file cache.
# 2023-01-03 02:16:09.468 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ef0c53e9.npz mode data from file cache.
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2023-01-03 02:16:09.499 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/10e5b441.npz mode data from file cache.
# 2023-01-03 02:16:09.535 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/33ea7062.npz mode data from file cache.
# 2023-01-03 02:16:09.562 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/8a134890.npz mode data from file cache.
# 2023-01-03 02:16:09.588 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/548eec24.npz mode data from file cache.
# 2023-01-03 02:16:09.615 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/e63d47fe.npz mode data from file cache.
# 2023-01-03 02:16:09.641 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/accb98e4.npz mode data from file cache.
# 2023-01-03 02:16:09.668 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/6c77208e.npz mode data from file cache.
# 2023-01-03 02:16:09.694 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/26c31481.npz mode data from file cache.
# 2023-01-03 02:16:09.722 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d6a9a5e1.npz mode data from file cache.
# 2023-01-03 02:16:09.748 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d408cef4.npz mode data from file cache.
# 2023-01-03 02:16:09.774 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ef0c53e9.npz mode data from file cache.

# %% [markdown]
# **Exercises**
#
# - What is the maximum width to support a single TE mode at 1310 nm?
# - For a Silicon Nitride (n=2) 400nm thick waveguide surrounded by SiO2 (n=1.44), what is the maximum width to support a single TE mode at 1550 nm?
# - For two 500x220nm Silicon waveguides surrounded by SiO2, what is the coupling length (100% coupling) for 200 nm gap?

# %% [markdown]
# ## Group index
#
# You can also compute the group index for a waveguide.

# %%
import gdsfactory.simulation.gtidy3d as gt
import numpy as np
import matplotlib.pyplot as plt

nm = 1e-3

ng = gt.modes.group_index(
    wg_width=500 * nm,
    wavelength=1.55,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore="si",
    nclad="sio2",
)
print(ng)
# Out:
# 2023-01-03 02:16:10.464 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/32ad155b.npz mode data from file cache.
# 2023-01-03 02:16:10.485 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/efa8c237.npz mode data from file cache.
# 2023-01-03 02:16:10.506 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/404735ef.npz mode data from file cache.
# 4.17024827003479

# %%
wavelengths = np.arange(1500, 1601, 50) * 1e-3
wg_widths = np.arange(400, 601, 50) * 1e-3

wg_settings = dict(
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore="si",
    nclad="sio2",
)

for wg_width in wg_widths:
    ng = [
        gt.modes.group_index(wavelength=wavelength, wg_width=wg_width, **wg_settings)
        for wavelength in wavelengths
    ]
    plt.plot(wavelengths, ng, label=f"{wg_width*1e3}")

plt.legend()
plt.xlabel("Wavelength (um)")
plt.xlabel("ng")
# Out:
# 2023-01-03 02:16:10.534 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/db70ae1c.npz mode data from file cache.
# 2023-01-03 02:16:10.556 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/e2b9236e.npz mode data from file cache.
# 2023-01-03 02:16:10.580 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/8a9e2a9c.npz mode data from file cache.
# 2023-01-03 02:16:10.601 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ee828ce2.npz mode data from file cache.
# 2023-01-03 02:16:10.623 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/01cfdbc2.npz mode data from file cache.
# 2023-01-03 02:16:10.645 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/a33c77fc.npz mode data from file cache.
# 2023-01-03 02:16:10.665 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ad20a498.npz mode data from file cache.
# 2023-01-03 02:16:10.686 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/bbc431bc.npz mode data from file cache.
# 2023-01-03 02:16:10.708 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/db706789.npz mode data from file cache.
# 2023-01-03 02:16:10.741 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/7addc938.npz mode data from file cache.
# 2023-01-03 02:16:10.762 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/fbea5e16.npz mode data from file cache.
# 2023-01-03 02:16:10.785 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/f980cdf3.npz mode data from file cache.
# 2023-01-03 02:16:10.805 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/f39af794.npz mode data from file cache.
# 2023-01-03 02:16:10.826 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/f322cd74.npz mode data from file cache.
# 2023-01-03 02:16:10.848 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d9f76608.npz mode data from file cache.
# 2023-01-03 02:16:10.870 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/e1af5407.npz mode data from file cache.
# 2023-01-03 02:16:10.891 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/3438337e.npz mode data from file cache.
# 2023-01-03 02:16:10.913 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d223d7bc.npz mode data from file cache.
# 2023-01-03 02:16:10.934 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/69370b5a.npz mode data from file cache.
# 2023-01-03 02:16:10.956 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/8eff82a6.npz mode data from file cache.
# 2023-01-03 02:16:10.977 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/1644b179.npz mode data from file cache.
# 2023-01-03 02:16:10.997 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/32ad155b.npz mode data from file cache.
# 2023-01-03 02:16:11.015 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/efa8c237.npz mode data from file cache.
# 2023-01-03 02:16:11.036 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/404735ef.npz mode data from file cache.
# 2023-01-03 02:16:11.057 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/59b63da9.npz mode data from file cache.
# 2023-01-03 02:16:11.078 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/3ff08735.npz mode data from file cache.
# 2023-01-03 02:16:11.099 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/f7fd487f.npz mode data from file cache.
# 2023-01-03 02:16:11.121 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/5c3c4d82.npz mode data from file cache.
# 2023-01-03 02:16:11.142 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/77e12ccd.npz mode data from file cache.
# 2023-01-03 02:16:11.164 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ac22b51c.npz mode data from file cache.
# 2023-01-03 02:16:11.184 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/3af735b0.npz mode data from file cache.
# 2023-01-03 02:16:11.205 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/03d8ba20.npz mode data from file cache.
# 2023-01-03 02:16:11.227 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/6d5f5f97.npz mode data from file cache.
# 2023-01-03 02:16:11.248 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d0700ab9.npz mode data from file cache.
# 2023-01-03 02:16:11.269 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d4c1b681.npz mode data from file cache.
# 2023-01-03 02:16:11.291 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/732df3db.npz mode data from file cache.
# 2023-01-03 02:16:11.312 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/f2834600.npz mode data from file cache.
# 2023-01-03 02:16:11.333 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d0570d8b.npz mode data from file cache.
# 2023-01-03 02:16:11.355 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/9e405786.npz mode data from file cache.
# 2023-01-03 02:16:11.375 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/10629d02.npz mode data from file cache.
# 2023-01-03 02:16:11.395 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d6451ecc.npz mode data from file cache.
# 2023-01-03 02:16:11.417 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/1f79f8ed.npz mode data from file cache.
# 2023-01-03 02:16:11.439 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/c0b7d21b.npz mode data from file cache.
# 2023-01-03 02:16:11.459 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ba05adb0.npz mode data from file cache.
# 2023-01-03 02:16:11.480 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/a0d874c3.npz mode data from file cache.

# %% [markdown]
# ## Bend modes
#
# You can compute bend modes specifying the bend radius.

# %%
strip_bend = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    bend_radius=3,
    ncore="si",
    nclad="sio2",
)

# %%
# lets plot the fundamental TE mode
strip_bend.plot_Ex(0)
strip_bend.plot_Ey(0)
# Out:
# 2023-01-03 02:16:11.668 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/9e1ab14b.npz mode data from file cache.

# %%
# lets plot the fundamental TM mode
strip_bend.plot_Ex(1)
strip_bend.plot_Ey(1)

# %% [markdown]
# ## Bend loss
#
# You can also compute the losses coming from the mode mismatch from the bend into a straight waveguide.
# To compute the bend loss due to mode mismatch you can calculate the mode overlap of the straight mode and the bent mode.
# Because there are two mode mismatch interfaces the total loss due to mode mismatch will be squared (from bend to straight and from straight to bend).
#
# ![](https://i.imgur.com/M1Yysdr.png)
#
# [from paper](https://ieeexplore.ieee.org/ielaam/50/8720127/8684870-aam.pdf)

# %%
import gdsfactory.simulation.gtidy3d as gt
import matplotlib.pyplot as plt

r, integral = gt.modes.sweep_bend_loss(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    bend_radius_min=2.0,
    bend_radius_max=5,
    steps=4,
    mode_index=0,
    ncore="si",
    nclad="sio2",
)

plt.title('Bend90 loss for TE polarization')
plt.plot(r, integral, ".")
plt.xlabel("bend radius (um)")
plt.ylabel("Transmission")
plt.show()
# Out:
# 0it [00:00, ?it/s]
# 2023-01-03 02:16:12.733 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/32ad155b.npz mode data from file cache.
# 2023-01-03 02:16:12.756 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/b61d8db9.npz mode data from file cache.
# 2023-01-03 02:16:12.776 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/9e1ab14b.npz mode data from file cache.
# 2023-01-03 02:16:12.798 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/b60c413e.npz mode data from file cache.
# 2023-01-03 02:16:12.821 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/fe139da7.npz mode data from file cache.

# %%
plt.title('Bend90 loss for TE polarization')
plt.plot(r, -10*np.log10(integral), ".")
plt.xlabel("bend radius (um)")
plt.ylabel("Loss (dB)")
plt.show()

# %%
import gdsfactory.simulation.gtidy3d as gt
import matplotlib.pyplot as plt

r, integral = gt.modes.sweep_bend_loss(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    bend_radius_min=3.0,
    bend_radius_max=20,
    steps=4,
    mode_index=1,
    ncore="si",
    nclad="sio2",
)

plt.title('Bend90 loss for TM polarization')
plt.ylim(ymin = min(integral), ymax=1)
plt.plot(r, integral, ".")
plt.xlabel("bend radius (um)")
plt.ylabel("Transmission")
plt.show()
# Out:
# 0it [00:00, ?it/s]
# 2023-01-03 02:16:13.087 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/32ad155b.npz mode data from file cache.
# 2023-01-03 02:16:13.108 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/9e1ab14b.npz mode data from file cache.
# 2023-01-03 02:16:13.131 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/24a6c53e.npz mode data from file cache.
# 2023-01-03 02:16:13.154 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/c7b81884.npz mode data from file cache.
# 2023-01-03 02:16:13.176 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/736aea86.npz mode data from file cache.

# %%
plt.plot(r, -10*np.log10(integral), ".")
plt.title('Bend90 loss for TM polarization')
plt.xlabel("bend radius (um)")
plt.ylabel("Loss (dB)")
plt.show()

# %% [markdown]
# **Exercises**
#
# - For a 500nm wide 220nm thick Silicon waveguide surrounded by SiO2, what is the minimum bend radius to have less than 0.04dB loss for TE polarization at 1550nm?
# - For a 500nm wide 220nm thick Silicon waveguide surrounded by SiO2, what is the minimum bend radius to have 99% power transmission for TM polarization at 1550nm?

# %% [markdown]
# ## Waveguide coupler
#
# You can also compute the modes of a waveguide coupler.
#
# ```
#         wg_width1     wg_width2
#         <------->     <------->
#          _______   |   _______   __
#         |       |  |  |       | |
#         |       |  |  |       | |
#         |       |_____|       | | wg_thickness
#         |slab_thickness       | |
#         |_____________________| |__
#                 <----->
#                   gap
#
#
# ```

# %%
c = gt.modes.WaveguideCoupler(
    wavelength=1.55,
    wg_width1=500 * nm,
    wg_width2=500 * nm,
    gap=200 * nm,
    wg_thickness=220 * nm,
    slab_thickness=100 * nm,
    ncore="si",
    nclad="sio2",
)
c.plot_index()

# %%
c.plot_Ex(0)
# Out:
# 2023-01-03 02:16:14.525 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:589 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/52ba9e71.npz mode data to file cache.

# %%
c.plot_Ex(1)

# %%
c = gt.modes.WaveguideCoupler(
    wavelength=1.55,
    wg_width1=500 * nm,
    wg_width2=500 * nm,
    gap=200 * nm,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore="si",
    nclad="sio2",
)
c.plot_index()

# %%
c.plot_Ex(0)
# Out:
# 2023-01-03 02:16:16.285 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:589 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ed01fcda.npz mode data to file cache.

# %%
c.plot_Ex(1)

# %%
import gdsfactory.simulation.gtidy3d as gt
import matplotlib.pyplot as plt

# %%
nm = 1e-3
si = gt.modes.si
sio2 = gt.modes.sio2
c = gt.modes.WaveguideCoupler(
    wavelength=1.55,
    wg_width1=500 * nm,
    wg_width2=500 * nm,
    gap=200 * nm,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore="si",
    nclad="sio2",
)
c.plot_index()

# %%
gaps = [150, 200, 250, 300]
coupling_length = [
    gt.modes.WaveguideCoupler(
        wavelength=1.55,
        wg_width1=500 * nm,
        wg_width2=500 * nm,
        gap=gap * nm,
        wg_thickness=220 * nm,
        slab_thickness=0 * nm,
        ncore="si",
        nclad="sio2",
    ).find_coupling(power_ratio=1)
    for gap in gaps
]
# Out:
# 2023-01-03 02:16:17.941 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:589 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/0b731432.npz mode data to file cache.
# 2023-01-03 02:16:17.960 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:424 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ed01fcda.npz mode data from file cache.
# 2023-01-03 02:16:18.844 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:589 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/b5e46470.npz mode data to file cache.
# 2023-01-03 02:16:19.545 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:589 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/e48d53b5.npz mode data to file cache.

# %%
plt.plot(gaps, coupling_length, ".")
plt.xlabel("gap (nm)")
plt.ylabel("100% coupling length (um)")
